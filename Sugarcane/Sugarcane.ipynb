# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS=3
EPOCHS=50
dataset_path ="D:\dataset\Leaf\Sugarcane"

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=32
)
# Out:
# Found 425 files belonging to 4 classes.

# %%
class_name = dataset.class_names
class_name
# Out:
# ['Sugarcane__bacterial_blight',
#  'Sugarcane__healthy',
#  'Sugarcane__red_rot',
#  'Sugarcane__rust']

# %%
len(dataset)
# Out:
# 14

# %%
plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range (12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_name[label_batch[i]])
        plt.axis("off")

# %%
train_data = dataset.take(11)
len(train_data)
# Out:
# 11

# %%
test_data = dataset.skip(11)
len(test_data)
# Out:
# 3

# %%
validation_dataset = test_data.take(1)
len(validation_dataset)
# Out:
# 1

# %%
test_data = test_data.skip(1)
len(test_data)
# Out:
# 2

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shffle=True , shuffle_size=1000 ):
    
    ds_size = len(ds)
    
    if shffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_data = ds.take(train_size)    
    validation_dataset = ds.skip(train_size).take(val_size)
    test_data = ds.skip(train_size).skip(val_size)
    
    return train_data,validation_dataset,test_data

# %%
train_data,validation_dataset,test_data = get_dataset_partitions_tf(dataset)

# %%
train_data = train_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_data = test_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomContrast(0.2),
    layers.experimental.preprocessing.RandomTranslation(0.2, 0.2),
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 6

model = tf.keras.Sequential([
    resize_and_rescale,
    data_augmentation,  # Add data augmentation here
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 256)         295168
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 256)         590080
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 256)          0
#  2D)
#
#  flatten (Flatten)           (32, 9216)                0
#
#  dense (Dense)               (32, 256)                 2359552
#
#  dense_1 (Dense)             (32, 6)                   1542
#
# =================================================================
# Total params: 3,339,590
# Trainable params: 3,339,590
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    batch_size=BATCH_SIZE,
    validation_data=validation_dataset,
    verbose=1,
    epochs=50,
)
# Out:
# Epoch 1/50
# 11/11 [==============================] - 93s 6s/step - loss: 1.5477 - accuracy: 0.2340 - val_loss: 1.3871 - val_accuracy: 0.3438
# Epoch 2/50
# 11/11 [==============================] - 20s 2s/step - loss: 1.4202 - accuracy: 0.2614 - val_loss: 1.4722 - val_accuracy: 0.1250
# Epoch 3/50
# 11/11 [==============================] - 19s 2s/step - loss: 1.3961 - accuracy: 0.2827 - val_loss: 1.3787 - val_accuracy: 0.3750
# Epoch 4/50
# 11/11 [==============================] - 20s 2s/step - loss: 1.3827 - accuracy: 0.3161 - val_loss: 1.4229 - val_accuracy: 0.1250
# Epoch 5/50
# 11/11 [==============================] - 20s 2s/step - loss: 1.3321 - accuracy: 0.3040 - val_loss: 1.2961 - val_accuracy: 0.4375
# Epoch 6/50
# 11/11 [==============================] - 20s 2s/step - loss: 1.2959 - accuracy: 0.3587 - val_loss: 1.3145 - val_accuracy: 0.2812
# Epoch 7/50
# 11/11 [==============================] - 21s 2s/step - loss: 1.2747 - accuracy: 0.4012 - val_loss: 1.2731 - val_accuracy: 0.3750
# Epoch 8/50
# 11/11 [==============================] - 20s 2s/step - loss: 1.1732 - accuracy: 0.4742 - val_loss: 1.1606 - val_accuracy: 0.5000
# Epoch 9/50
# 11/11 [==============================] - 19s 2s/step - loss: 1.1515 - accuracy: 0.4833 - val_loss: 1.1100 - val_accuracy: 0.5938
# Epoch 10/50
# 11/11 [==============================] - 20s 2s/step - loss: 1.0465 - accuracy: 0.5957 - val_loss: 1.3831 - val_accuracy: 0.4062
# Epoch 11/50
# 11/11 [==============================] - 21s 2s/step - loss: 0.9726 - accuracy: 0.6444 - val_loss: 1.1194 - val_accuracy: 0.5312
# Epoch 12/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.9726 - accuracy: 0.5897 - val_loss: 0.9332 - val_accuracy: 0.5938
# Epoch 13/50
# 11/11 [==============================] - 20s 2s/step - loss: 1.1170 - accuracy: 0.5289 - val_loss: 1.1663 - val_accuracy: 0.5000
# Epoch 14/50
# 11/11 [==============================] - 21s 2s/step - loss: 0.9727 - accuracy: 0.6079 - val_loss: 1.1133 - val_accuracy: 0.5938
# Epoch 15/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.8744 - accuracy: 0.6778 - val_loss: 0.9731 - val_accuracy: 0.6875
# Epoch 16/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.8831 - accuracy: 0.6535 - val_loss: 1.0991 - val_accuracy: 0.5312
# Epoch 17/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.8560 - accuracy: 0.6960 - val_loss: 0.8257 - val_accuracy: 0.6250
# Epoch 18/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.8221 - accuracy: 0.6687 - val_loss: 0.9769 - val_accuracy: 0.5938
# Epoch 19/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.8067 - accuracy: 0.6657 - val_loss: 0.7877 - val_accuracy: 0.6250
# Epoch 20/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.7815 - accuracy: 0.6900 - val_loss: 0.7533 - val_accuracy: 0.6875
# Epoch 21/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.7985 - accuracy: 0.6657 - val_loss: 0.7165 - val_accuracy: 0.6875
# Epoch 22/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.7203 - accuracy: 0.7082 - val_loss: 0.6918 - val_accuracy: 0.6875
# Epoch 23/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.7099 - accuracy: 0.7112 - val_loss: 0.7285 - val_accuracy: 0.6250
# Epoch 24/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.7509 - accuracy: 0.6930 - val_loss: 0.8615 - val_accuracy: 0.5938
# Epoch 25/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.7146 - accuracy: 0.6869 - val_loss: 0.6579 - val_accuracy: 0.7812
# Epoch 26/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.6651 - accuracy: 0.7295 - val_loss: 0.5440 - val_accuracy: 0.7500
# Epoch 27/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.5760 - accuracy: 0.7599 - val_loss: 0.8311 - val_accuracy: 0.6875
# Epoch 28/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.5847 - accuracy: 0.7660 - val_loss: 0.9903 - val_accuracy: 0.5312
# Epoch 29/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.7409 - accuracy: 0.7204 - val_loss: 0.8251 - val_accuracy: 0.6250
# Epoch 30/50
# 11/11 [==============================] - 21s 2s/step - loss: 0.6691 - accuracy: 0.7234 - val_loss: 0.8243 - val_accuracy: 0.6250
# Epoch 31/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.6120 - accuracy: 0.7629 - val_loss: 0.9818 - val_accuracy: 0.6250
# Epoch 32/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.5974 - accuracy: 0.7538 - val_loss: 0.7335 - val_accuracy: 0.6250
# Epoch 33/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.5580 - accuracy: 0.7629 - val_loss: 0.5764 - val_accuracy: 0.8750
# Epoch 34/50
# 11/11 [==============================] - 22s 2s/step - loss: 0.5792 - accuracy: 0.7781 - val_loss: 0.4823 - val_accuracy: 0.7812
# Epoch 35/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.5057 - accuracy: 0.8116 - val_loss: 0.4526 - val_accuracy: 0.8125
# Epoch 36/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.5291 - accuracy: 0.7994 - val_loss: 0.4424 - val_accuracy: 0.8750
# Epoch 37/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.4564 - accuracy: 0.8146 - val_loss: 0.4482 - val_accuracy: 0.8438
# Epoch 38/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.4699 - accuracy: 0.8085 - val_loss: 0.7946 - val_accuracy: 0.7500
# Epoch 39/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.5326 - accuracy: 0.7933 - val_loss: 1.0741 - val_accuracy: 0.5625
# Epoch 40/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.4930 - accuracy: 0.8024 - val_loss: 0.4495 - val_accuracy: 0.8125
# Epoch 41/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.6298 - accuracy: 0.7568 - val_loss: 0.4971 - val_accuracy: 0.8438
# Epoch 42/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.5024 - accuracy: 0.8237 - val_loss: 0.3241 - val_accuracy: 0.8750
# Epoch 43/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.4345 - accuracy: 0.8055 - val_loss: 0.4152 - val_accuracy: 0.8438
# Epoch 44/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.4067 - accuracy: 0.8359 - val_loss: 0.3458 - val_accuracy: 0.9062
# Epoch 45/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.4409 - accuracy: 0.8146 - val_loss: 0.9967 - val_accuracy: 0.6875
# Epoch 46/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.5794 - accuracy: 0.7903 - val_loss: 0.4971 - val_accuracy: 0.8438
# Epoch 47/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.4803 - accuracy: 0.7933 - val_loss: 0.5082 - val_accuracy: 0.8438
# Epoch 48/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.4739 - accuracy: 0.8085 - val_loss: 0.5115 - val_accuracy: 0.8125
# Epoch 49/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.5838 - accuracy: 0.7629 - val_loss: 0.4800 - val_accuracy: 0.7812
# Epoch 50/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.4968 - accuracy: 0.8116 - val_loss: 0.4092 - val_accuracy: 0.8750

# %%
scores = model.evaluate(test_data)
# Out:
# 2/2 [==============================] - 38s 337ms/step - loss: 0.3593 - accuracy: 0.8906

# %%
model.save("Sugarcane.h5")

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_name[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_data.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_name[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
