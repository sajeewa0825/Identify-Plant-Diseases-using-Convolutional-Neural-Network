# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS=3
EPOCHS=50
dataset_path ="D:\dataset\Leaf\Tea"

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=32
)
# Out:
# Found 1845 files belonging to 6 classes.

# %%
class_name = dataset.class_names
class_name
# Out:
# ['Tea__algal_leaf',
#  'Tea__anthracnose',
#  'Tea__bird_eye_spot',
#  'Tea__brown_blight',
#  'Tea__healthy',
#  'Tea__red_leaf_spot']

# %%
len(dataset)
# Out:
# 58

# %%
plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range (12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_name[label_batch[i]])
        plt.axis("off")

# %%
train_data = dataset.take(46)
len(train_data)
# Out:
# 46

# %%
test_data = dataset.skip(46)
len(test_data)
# Out:
# 12

# %%
validation_dataset = test_data.take(5)
len(validation_dataset)
# Out:
# 5

# %%
test_data = test_data.skip(5)
len(test_data)
# Out:
# 7

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shffle=True , shuffle_size=1000 ):
    
    ds_size = len(ds)
    
    if shffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_data = ds.take(train_size)    
    validation_dataset = ds.skip(train_size).take(val_size)
    test_data = ds.skip(train_size).skip(val_size)
    
    return train_data,validation_dataset,test_data

# %%
train_data,validation_dataset,test_data = get_dataset_partitions_tf(dataset)

# %%
train_data = train_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_data = test_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomContrast(0.2),
    layers.experimental.preprocessing.RandomTranslation(0.2, 0.2),
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 6

model = tf.keras.Sequential([
    resize_and_rescale,
    data_augmentation,  # Add data augmentation here
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 256)         295168
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 256)         590080
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 256)          0
#  2D)
#
#  flatten (Flatten)           (32, 9216)                0
#
#  dense (Dense)               (32, 256)                 2359552
#
#  dense_1 (Dense)             (32, 6)                   1542
#
# =================================================================
# Total params: 3,339,590
# Trainable params: 3,339,590
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    batch_size=BATCH_SIZE,
    validation_data=validation_dataset,
    verbose=1,
    epochs=50,
)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 162s 3s/step - loss: 1.4631 - accuracy: 0.3190 - val_loss: 1.2655 - val_accuracy: 0.4437
# Epoch 2/50
# 46/46 [==============================] - 81s 2s/step - loss: 1.0457 - accuracy: 0.4682 - val_loss: 0.9518 - val_accuracy: 0.4125
# Epoch 3/50
# 46/46 [==============================] - 81s 2s/step - loss: 1.0692 - accuracy: 0.4627 - val_loss: 0.9591 - val_accuracy: 0.5000
# Epoch 4/50
# 46/46 [==============================] - 115s 2s/step - loss: 0.9166 - accuracy: 0.5339 - val_loss: 0.8671 - val_accuracy: 0.5688
# Epoch 5/50
# 46/46 [==============================] - 76s 2s/step - loss: 0.9893 - accuracy: 0.5195 - val_loss: 0.8560 - val_accuracy: 0.5625
# Epoch 6/50
# 46/46 [==============================] - 93s 2s/step - loss: 0.8963 - accuracy: 0.5380 - val_loss: 0.9229 - val_accuracy: 0.5250
# Epoch 7/50
# 46/46 [==============================] - 82s 2s/step - loss: 0.7851 - accuracy: 0.6133 - val_loss: 0.7905 - val_accuracy: 0.6062
# Epoch 8/50
# 46/46 [==============================] - 78s 2s/step - loss: 0.8613 - accuracy: 0.5667 - val_loss: 0.7611 - val_accuracy: 0.6125
# Epoch 9/50
# 46/46 [==============================] - 75s 2s/step - loss: 0.7873 - accuracy: 0.6119 - val_loss: 1.1771 - val_accuracy: 0.4938
# Epoch 10/50
# 46/46 [==============================] - 80s 2s/step - loss: 0.8165 - accuracy: 0.5962 - val_loss: 0.7481 - val_accuracy: 0.5500
# Epoch 11/50
# 46/46 [==============================] - 73s 2s/step - loss: 0.8354 - accuracy: 0.5927 - val_loss: 0.6911 - val_accuracy: 0.6313
# Epoch 12/50
# 46/46 [==============================] - 84s 2s/step - loss: 0.7957 - accuracy: 0.6201 - val_loss: 0.9211 - val_accuracy: 0.5375
# Epoch 13/50
# 46/46 [==============================] - 78s 2s/step - loss: 0.7362 - accuracy: 0.6393 - val_loss: 0.5875 - val_accuracy: 0.7000
# Epoch 14/50
# 46/46 [==============================] - 76s 2s/step - loss: 0.7032 - accuracy: 0.6564 - val_loss: 1.1406 - val_accuracy: 0.4688
# Epoch 15/50
# 46/46 [==============================] - 73s 2s/step - loss: 0.7832 - accuracy: 0.6393 - val_loss: 0.7895 - val_accuracy: 0.6250
# Epoch 16/50
# 46/46 [==============================] - 74s 2s/step - loss: 0.6994 - accuracy: 0.6845 - val_loss: 0.4424 - val_accuracy: 0.8062
# Epoch 17/50
# 46/46 [==============================] - 74s 2s/step - loss: 0.6734 - accuracy: 0.7029 - val_loss: 0.4749 - val_accuracy: 0.8188
# Epoch 18/50
# 46/46 [==============================] - 80s 2s/step - loss: 0.6139 - accuracy: 0.7262 - val_loss: 0.5754 - val_accuracy: 0.7000
# Epoch 19/50
# 46/46 [==============================] - 76s 2s/step - loss: 0.5628 - accuracy: 0.7474 - val_loss: 0.8698 - val_accuracy: 0.5938
# Epoch 20/50
# 46/46 [==============================] - 4474s 99s/step - loss: 0.6969 - accuracy: 0.6804 - val_loss: 0.9511 - val_accuracy: 0.5562
# Epoch 21/50
# 46/46 [==============================] - 185s 4s/step - loss: 0.6597 - accuracy: 0.7084 - val_loss: 0.5063 - val_accuracy: 0.8000
# Epoch 22/50
# 46/46 [==============================] - 173s 4s/step - loss: 0.5950 - accuracy: 0.7139 - val_loss: 0.7562 - val_accuracy: 0.6750
# Epoch 23/50
# 46/46 [==============================] - 149s 3s/step - loss: 0.5915 - accuracy: 0.7310 - val_loss: 0.3838 - val_accuracy: 0.8687
# Epoch 24/50
# 46/46 [==============================] - 80s 2s/step - loss: 0.6124 - accuracy: 0.7440 - val_loss: 0.4426 - val_accuracy: 0.7437
# Epoch 25/50
# 46/46 [==============================] - 80s 2s/step - loss: 0.5381 - accuracy: 0.7515 - val_loss: 0.7886 - val_accuracy: 0.6375
# Epoch 26/50
# 46/46 [==============================] - 81s 2s/step - loss: 0.4937 - accuracy: 0.7953 - val_loss: 0.7793 - val_accuracy: 0.6875
# Epoch 27/50
# 46/46 [==============================] - 84s 2s/step - loss: 0.6793 - accuracy: 0.7153 - val_loss: 0.6300 - val_accuracy: 0.6500
# Epoch 28/50
# 46/46 [==============================] - 88s 2s/step - loss: 0.5117 - accuracy: 0.7830 - val_loss: 0.4829 - val_accuracy: 0.7500
# Epoch 29/50
# 46/46 [==============================] - 84s 2s/step - loss: 0.4695 - accuracy: 0.7933 - val_loss: 0.5082 - val_accuracy: 0.7563
# Epoch 30/50
# 46/46 [==============================] - 85s 2s/step - loss: 0.5352 - accuracy: 0.7721 - val_loss: 0.4189 - val_accuracy: 0.8188
# Epoch 31/50
# 46/46 [==============================] - 81s 2s/step - loss: 0.5709 - accuracy: 0.7673 - val_loss: 0.4834 - val_accuracy: 0.8000
# Epoch 32/50
# 46/46 [==============================] - 77s 2s/step - loss: 0.4852 - accuracy: 0.7906 - val_loss: 0.5536 - val_accuracy: 0.7563
# Epoch 33/50
# 46/46 [==============================] - 77s 2s/step - loss: 0.7557 - accuracy: 0.6742 - val_loss: 0.6701 - val_accuracy: 0.7125
# Epoch 34/50
# 46/46 [==============================] - 86s 2s/step - loss: 0.4574 - accuracy: 0.8077 - val_loss: 1.2691 - val_accuracy: 0.5813
# Epoch 35/50
# 46/46 [==============================] - 79s 2s/step - loss: 0.4539 - accuracy: 0.8036 - val_loss: 0.4579 - val_accuracy: 0.7875
# Epoch 36/50
# 46/46 [==============================] - 80s 2s/step - loss: 0.3860 - accuracy: 0.8385 - val_loss: 0.7344 - val_accuracy: 0.7000
# Epoch 37/50
# 46/46 [==============================] - 73s 2s/step - loss: 0.3815 - accuracy: 0.8453 - val_loss: 0.7933 - val_accuracy: 0.6750
# Epoch 38/50
# 46/46 [==============================] - 79s 2s/step - loss: 0.4871 - accuracy: 0.7995 - val_loss: 0.3513 - val_accuracy: 0.8375
# Epoch 39/50
# 46/46 [==============================] - 78s 2s/step - loss: 0.4587 - accuracy: 0.7995 - val_loss: 0.8259 - val_accuracy: 0.7063
# Epoch 40/50
# 46/46 [==============================] - 84s 2s/step - loss: 0.4074 - accuracy: 0.8385 - val_loss: 0.4990 - val_accuracy: 0.7625
# Epoch 41/50
# 46/46 [==============================] - 82s 2s/step - loss: 0.3828 - accuracy: 0.8392 - val_loss: 0.5269 - val_accuracy: 0.7375
# Epoch 42/50
# 46/46 [==============================] - 86s 2s/step - loss: 0.3714 - accuracy: 0.8330 - val_loss: 0.4533 - val_accuracy: 0.7500
# Epoch 43/50
# 46/46 [==============================] - 87s 2s/step - loss: 0.3080 - accuracy: 0.8631 - val_loss: 0.5063 - val_accuracy: 0.7563
# Epoch 44/50
# 46/46 [==============================] - 75s 2s/step - loss: 0.3503 - accuracy: 0.8549 - val_loss: 0.4693 - val_accuracy: 0.7563
# Epoch 45/50
# 46/46 [==============================] - 76s 2s/step - loss: 0.3281 - accuracy: 0.8597 - val_loss: 0.8594 - val_accuracy: 0.7312
# Epoch 46/50
# 46/46 [==============================] - 75s 2s/step - loss: 0.4362 - accuracy: 0.8255 - val_loss: 0.6306 - val_accuracy: 0.7688
# Epoch 47/50
# 46/46 [==============================] - 77s 2s/step - loss: 0.3514 - accuracy: 0.8556 - val_loss: 0.8545 - val_accuracy: 0.7250
# Epoch 48/50
# 46/46 [==============================] - 75s 2s/step - loss: 0.3612 - accuracy: 0.8549 - val_loss: 0.3633 - val_accuracy: 0.8125
# Epoch 49/50
# 46/46 [==============================] - 77s 2s/step - loss: 0.2861 - accuracy: 0.8802 - val_loss: 0.4714 - val_accuracy: 0.8188
# Epoch 50/50
# 46/46 [==============================] - 76s 2s/step - loss: 0.3755 - accuracy: 0.8398 - val_loss: 0.4193 - val_accuracy: 0.8062

# %%
scores = model.evaluate(test_data)
# Out:
# 7/7 [==============================] - 46s 330ms/step - loss: 0.3366 - accuracy: 0.8482

# %%
model.save("Tea.h5")

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_name[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_data.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_name[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
